# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from nltk.tokenize import sent_tokenize

# Load the original dataset
data = pd.read_csv('combined_dormitory_data.csv')

# Ensure all values in the 'text' column are treated as strings
data['text'] = data['text'].astype(str)

# Load the sentiment analysis model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment-latest")
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment-latest")

# Define a function to predict sentiment for each comment
def get_sentiment(comment):
    inputs = tokenizer(comment, return_tensors="pt", truncation=True, max_length=512, padding=True)
    with torch.no_grad():
        logits = model(**inputs).logits
    predicted_class_id = torch.argmax(logits, dim=-1).item()
    return predicted_class_id

# Map sentiment labels (0: negative, 1: neutral, 2: positive)
sentiment_labels = {0: "negative", 1: "neutral", 2: "positive"}

# Create a list to store the new rows
new_rows = []

# Iterate through each review, tokenize into sentences, and get sentiment
for index, row in data.iterrows():
    original_review = row['text']
    sentences = sent_tokenize(original_review)  # Split review into sentences
    
    for sentence in sentences:
        sentiment = sentiment_labels[get_sentiment(sentence)]
        new_rows.append({'date': row['date'], 
                         'channel_name': row['channel_name'],
                         'message_id': row['message_id'],
                         'text': original_review,
                         'sentiment': sentiment,
                         'rephrased_news': row['rephrased_news'],
                         'title': row['title'],
                         'topic': row['topic'],
                         'location_type': row['location_type'],
                         'location': row['location'],
                         'latitude': row['latitude'],
                         'longitude': row['longitude'],
                         'sentence': sentence,}) 

# Create a new DataFrame from the new rows
sentiment_data = pd.DataFrame(new_rows)

# # Merge with the original data if needed
# merged_data = pd.merge(data, sentiment_data, on=['place_id', 'text'], how='inner')

# # Save the updated data with sentiment column to a new CSV file
# merged_data.to_csv('Merged_Labeled_Reviews.csv', index=False)

# Print the first few rows of the merged data
sentiment_data.head(10)
# Out:
# C:\python\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# C:\python\Lib\site-packages\torch\_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#                         date        channel_name  message_id  \
# 0  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI         392
# 1  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI         392
# 2  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI         392
# 3  2023-12-05T00:03:14+00:00  Dormitory 7 of KPI         394
# 4  2023-12-05T00:03:14+00:00  Dormitory 7 of KPI         394
# 5  2023-12-05T00:03:14+00:00  Dormitory 7 of KPI         394
# 6  2023-12-05T00:03:14+00:00  Dormitory 7 of KPI         394
# 7  2023-12-05T00:03:14+00:00  Dormitory 7 of KPI         394
# 8  2023-12-05T00:03:14+00:00  Dormitory 7 of KPI         394
# 9  2023-12-05T00:03:14+00:00  Dormitory 7 of KPI         394
#
#                                                 text sentiment  \
# 0  **🌡️ Repair work on heating networks**\n\nToda...  negative
# 1  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 2  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 3  **News from the student campus**\n🔸 An analysi...   neutral
# 4  **News from the student campus**\n🔸 An analysi...   neutral
# 5  **News from the student campus**\n🔸 An analysi...   neutral
# 6  **News from the student campus**\n🔸 An analysi...   neutral
# 7  **News from the student campus**\n🔸 An analysi...   neutral
# 8  **News from the student campus**\n🔸 An analysi...   neutral
# 9  **News from the student campus**\n🔸 An analysi...  positive
#
#                                       rephrased_news  \
# 0  Repair work on heating networks has resulted i...
# 1  Repair work on heating networks has resulted i...
# 2  Repair work on heating networks has resulted i...
# 3  An analysis of the financial and economic acti...
# 4  An analysis of the financial and economic acti...
# 5  An analysis of the financial and economic acti...
# 6  An analysis of the financial and economic acti...
# 7  An analysis of the financial and economic acti...
# 8  An analysis of the financial and economic acti...
# 9  An analysis of the financial and economic acti...
#
#                                     title                           topic  \
# 0           Heating Outage in Dormitories              Citizen Discomfort
# 1           Heating Outage in Dormitories              Citizen Discomfort
# 2           Heating Outage in Dormitories              Citizen Discomfort
# 3  Campus Renovations and Budget Approved  Improvements in Infrastructure
# 4  Campus Renovations and Budget Approved  Improvements in Infrastructure
# 5  Campus Renovations and Budget Approved  Improvements in Infrastructure
# 6  Campus Renovations and Budget Approved  Improvements in Infrastructure
# 7  Campus Renovations and Budget Approved  Improvements in Infrastructure
# 8  Campus Renovations and Budget Approved  Improvements in Infrastructure
# 9  Campus Renovations and Budget Approved  Improvements in Infrastructure
#
#     location_type             location   latitude  longitude  \
# 0  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 1  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 2  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 3  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 4  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 5  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 6  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 7  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 8  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 9  exact location  ['KPI Dormitory 7']  50.448522  30.449409
#
#                                             sentence
# 0  **🌡️ Repair work on heating networks**\n\nToda...
# 1    Estimated return time: 12:00 PM on November 12.
# 2                                         @kpicampus
# 3  **News from the student campus**\n🔸 An analysi...
# 4  A draft budget, procurement plan, and repair w...
# 5     🔹 The renovation of the **gym in dormitory No.
# 6  7, which will also be used as a shelter**, has...
# 7   🔸 The restoration of the stairs in dormitory No.
# 8                              4 has been completed.
# 9  ❤️ Take care of yourselves, use shelters durin...

# %%
# Load the dataset
data = sentiment_data

# Remove rows with "positive" in the "Sentiment" column
data_filtered = data[data['sentiment'] != 'positive']

# Print the first few rows of the filtered dataset
data_filtered.head()
# Out:
#                         date        channel_name  message_id  \
# 0  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI         392
# 1  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI         392
# 2  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI         392
# 3  2023-12-05T00:03:14+00:00  Dormitory 7 of KPI         394
# 4  2023-12-05T00:03:14+00:00  Dormitory 7 of KPI         394
#
#                                                 text sentiment  \
# 0  **🌡️ Repair work on heating networks**\n\nToda...  negative
# 1  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 2  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 3  **News from the student campus**\n🔸 An analysi...   neutral
# 4  **News from the student campus**\n🔸 An analysi...   neutral
#
#                                       rephrased_news  \
# 0  Repair work on heating networks has resulted i...
# 1  Repair work on heating networks has resulted i...
# 2  Repair work on heating networks has resulted i...
# 3  An analysis of the financial and economic acti...
# 4  An analysis of the financial and economic acti...
#
#                                     title                           topic  \
# 0           Heating Outage in Dormitories              Citizen Discomfort
# 1           Heating Outage in Dormitories              Citizen Discomfort
# 2           Heating Outage in Dormitories              Citizen Discomfort
# 3  Campus Renovations and Budget Approved  Improvements in Infrastructure
# 4  Campus Renovations and Budget Approved  Improvements in Infrastructure
#
#     location_type             location   latitude  longitude  \
# 0  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 1  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 2  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 3  exact location  ['KPI Dormitory 7']  50.448522  30.449409
# 4  exact location  ['KPI Dormitory 7']  50.448522  30.449409
#
#                                             sentence
# 0  **🌡️ Repair work on heating networks**\n\nToda...
# 1    Estimated return time: 12:00 PM on November 12.
# 2                                         @kpicampus
# 3  **News from the student campus**\n🔸 An analysi...
# 4  A draft budget, procurement plan, and repair w...

# %%
# # Save the filtered data to a new CSV file
# data_filtered.to_csv('Without_pos.csv', index=False)

# %%
from sklearn.cluster import AgglomerativeClustering
from sentence_transformers import SentenceTransformer
import pandas as pd
import nltk

nltk.download('punkt')

reviews = data['sentence'].dropna().tolist()

# Split each review into sentences and keep a mapping to the original review
split_reviews = []
original_review_map = []

for review in reviews:
    sentences = sent_tokenize(review)
    split_reviews.extend(sentences)
    original_review_map.extend([review] * len(sentences))  # Map sentences back to original reviews

# Load the model and encode the split sentences into embeddings
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
embeddings = model.encode(split_reviews)

# Perform Agglomerative Clustering with cosine affinity
agglomerative = AgglomerativeClustering(n_clusters=None, distance_threshold=0.91, affinity='cosine', linkage='average')
cluster_assignment = agglomerative.fit_predict(embeddings)

# Group sentences by their assigned cluster
clustered_reviews = {}
for i, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_reviews:
        clustered_reviews[cluster_id] = []
    clustered_reviews[cluster_id].append(split_reviews[i])

# Map each sentence back to its original review
sentence_to_review = {}
for i, sentence in enumerate(split_reviews):
    original_review = original_review_map[i]
    sentence_to_review[sentence] = original_review

# Display the clustered sentences with original mapping
print("\nClustered Sentences:")
for cluster_id, cluster_sentences in clustered_reviews.items():
    print(f"\nCluster {cluster_id}:")
    for sentence in cluster_sentences:
        print(f" - {sentence}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# C:\python\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Clustered Sentences:
#
# Cluster 0:
#  - **🌡️ Repair work on heating networks**
#
# Today from 9:00 AM, there is no hot water supply and heating in most dormitories.
#  - Estimated return time: 12:00 PM on November 12.
#  - @kpicampus
#  - **News from the student campus**
# 🔸 An analysis of the financial and economic activities of the student campus for the period 2021-2023 has been conducted.
#  - A draft budget, procurement plan, and repair work for 2024 have been prepared and approved.
#  - 🔹 The renovation of the **gym in dormitory No.
#  - 7, which will also be used as a shelter**, has been completed.
#  - 🔸 The restoration of the stairs in dormitory No.
#  - 4 has been completed.
#  - ❤️ Take care of yourselves, use shelters during air alerts!
#  - Student campus KPI @studmisto.
#  - **Contact us - ****@kpi_studmisto_bot****.
#  - Good luck!
#  - **
#  - ⚠️ **Emergency**
#
# Emergency power outage across the Shulyavka area and KPI.
#  - Estimated return time according to DTEK is 6:00 PM.
#  - If you need to recharge, approach the guards for a power bank.
#  - @kpicampus
#  - 💡**Power outages**
#
# Starting from May 16, hourly power outages may occur in Kyiv and the student campus according to the [schedule](https://www.dtek-kem.com.ua/ua/shutdowns) of Ukrenergo and DTEK.
#  - Preliminary outages may occur [from](https://t.me/suspilnenews/32727) 12:00 AM to 9:00 AM or from 4:00 PM to 12:00 AM.
#  - @kpicampus
#  - 🌡️ **Well, you get it**
#
# **Kyivteploenergo promises to finish work by 11:00 PM every day, but "something" is going off plan.
#  - **
#
# Estimated time: by the end of the month.
#  - Probably in 2024.
#  - @kpicampus
#  - 🟢 **Directorate 06.08**
#
# **Settlement**
# Will begin on August 26, and by the end of the week, there will be lists for settlement from faculties and institutes.
#  - In total, about 9,000 students are planned to be brought out for mixed learning.
#  - **Masters**
# By August 2, they were supposed to write a [request](https://docs.google.com/document/d/13FJxmoUKzXYeRo9T8oGxshdi3MXm1faIDpQwAO6Tk1E/edit?usp=sharing) for a change in payment format and extension of residence in the dormitory until August 31.
#  - If you haven't written a request, contact the manager.
#  - **Hot water**
# In some dormitories, there has been no hot water for 3 months due to major repair work.
#  - **Elevators**
# Due to the stabilization of electricity supply, the operation of most elevators will be restored.
#  - @kpicampus
#  - [​​](https://telegra.ph/file/b793c7b6b4d653e40c4f4.jpg)🙌 **Recruitment of volunteers to assist with settlement**
#
# We are looking for volunteers who are ready to help settle newcomers!
#  - This is a great opportunity to meet new people and make the lives of first-year students in the campus easier.
#  - If you have some free time and want to do something useful – fill out the [form at the link](https://forms.gle/3i48ThrZcRTxM3e68) **by August 25 inclusive.
#  - ** We look forward to having you on our team!
#  - @kpicampus
#  - 🌡 **Hot water outage**
#
# **Due to emergency work, there is no hot water in some dormitories due to Kyivteploenergo.
#  - **
#
# Hot water supply is planned to be restored by the evening of August 29.
#  - @kpicampus
#  - 🟢 **Administration**
#
# **Masters**
# Students who complete their master's studies in winter will be evicted.
#  - We remind you that previously, master's interns could continue to [stay until summer as external individuals.
#  - ](https://t.me/kpicampus/1504)
#
# **Heating**
# Heating is planned to be supplied according to the KMDA schedule — **around October 15.
#  - ** As usual, heating in the dormitories will be delayed by a week.
#  - **Payment**
# Payment in September was calculated at the rate of 4 people per room; starting in October, the payment amount will be calculated based on the [number of registered residents in the room](https://t.me/kpicampus/1059).
#  - If a student is settled in the middle of the month, the payment will change from the following month, not from the moment of their settlement.
#  - **"Laundry"**
# New washing machines are planned to be added to the dormitories to replace the old ones.
#  - **Illegal Residents**
# The surveillance cameras planned to be installed in the student campus will be directly connected to the DB office to reduce the number of illegal residents entering the dormitory.
#  - **Windows**
# The installation of new windows in Dormitory 4 is delayed due to incorrectly specified dimensions.
#  - @kpicampus
#  - 💧**May Without Water**
#
# There is no hot water supply in the dormitories due to a break in the heating network and the corresponding repair work until May 13 at 23:59.
#  - After their completion, hydraulic tests of the pipes will begin until the end of the month.
#  - The estimated completion date for all work and the return of water, according to Kyivteploenergo, is May 28 — 31.
#  - @kpicampus
#  - **🟢 Administration**
#
# **Shelters**
# Repairs are planned in 6 dormitories that have shelters by autumn.
#  - **Power Banks**
# For emergency charging, most dormitories have [power banks](https://t.me/ecokpi/142) available at the reception.
#  - If you do not have a power bank or it is in poor condition, please request a replacement at @kpicampus_bot.
#  - **Generators**
# Will only be used in case of power outages lasting more than 4 hours, and only for charging flashlights and phones.
#  - @kpicampus
#  - UPD: The hot water supply shutdown has been extended to June 10.
#  - @kpicampus
#  - 🚰 **Message from the Future**
#
# According to Kyivteploenergo, there will be no water supply starting tomorrow at 9:00 AM.
#  - The estimated time for the return of water supply will be communicated by Kyivteploenergo tomorrow, based on the volume of work.
#  - @kpicampus
#  - UPD: The disconnection of hot water supply has been extended until June 10.
#  - @kpicampus
#  - 🟢 **Administration**
#
# **Settlement**
# The settlement algorithm for the summer will be announced tomorrow, based on a similar, [last year's principle](https://t.me/kpicampus/1580).
#  - The number of settlement places for the next academic year is planned to increase by 1,500.
#  - Instructions for the settlement itself will be available by July 17.
#  - **Elevators**
# Elevators are starting to resume operation, but it is necessary to monitor the disconnection schedules to avoid getting stuck in the elevator in the middle of the night.
#  - @kpicampus
#  - 🟢 **Administration 06.08**
#
# **Settlement**
# It will start on August 26, and by the end of the week, there will be lists for settlement from faculties and institutes.
#  - A total of about 9,000 students are planned to be brought to mixed learning.
#  - **Masters**
# By August 2, they should have written a [request](https://docs.google.com/document/d/13FJxmoUKzXYeRo9T8oGxshdi3MXm1faIDpQwAO6Tk1E/edit?usp=sharing) for a change in payment format and extension of residence in the dormitory until August 31.
#  - If you did not write a request, please contact the manager.
#  - **Hot Water**
# In some dormitories, there has been no hot water for 3 months due to major repair work.
#  - **Elevators**
# Due to the stabilization of electricity supply, the operation of most elevators will be restored.
#  - @kpicampus
#  - [🎸](https://telegra.ph/file/159f89439938f4ce0f8e8.png) **Guitar Evening**
#
# The heat is gradually subsiding, and the holidays are coming to an end.
#  - Spend one of the last summer evenings at the **Guitar Evening** on **August 23 at 18:00**.
#  - Visit [KPI Coliseum](https://maps.app.goo.gl/h57HaE7TBMSJS4fXA) in **bright clothing** to enjoy live music in the company of like-minded people.
#  - To enter, you need to fill out the [form](https://docs.google.com/forms/d/e/1FAIpQLSdIHYEO4ZuYGDWak_ZhXVk_5cxSXlxm0diaaRgj5zayHonQpQ/viewform?usp=sf_link) by **August 22 at 23:59** and donate **100** **₴** so that we can continue to hold events in free Ukraine.
#  - Note that the entrance fee will be **150** **₴**.
#  - 🌡 **Disconnection of Hot Water**
#
# **Due to emergency work by Kyivteploenergo, there is no hot water in some dormitories.
#  - **
#
# Hot water supply is planned to be restored by the evening of August 29.
#  - @kpicampus
#  - **Promotion**
#
# **Hot water has been turned off only for dormitory 8.
#  - A plumber is conducting repair work, and it should be ready by the evening.
#  - **
#  - 💧 **Water Disconnection**
#
# **Due to emergency work by Kyivteploenergo, there may be interruptions in water supply in some dormitories.
#  - **
#
# Water supply is planned to be restored by 14:00 on September 16.
#  - @kpicampus
#  - 🌡️ **Heating Network Repairs**
#
# In some dormitories on Braichevskogo and Yangel streets, there is no hot water supply.
#  - Estimated return time, according to Kyivteploenergo: tomorrow at 15:00.
#  - @kpicampus
#  - **🌡️ Repair Work on Heating Networks**
#
# Today from 9:00, there is no hot water supply and heating in most dormitories.
#  - Estimated return time: 12:00 on November 12.
#  - @kpicampus
#  - Dear residents, due to pipe repairs in the basement, there will be no water temporarily on the right side.
#  - **🌡️ Heating Network Emergency**
#
# In the dormitories on Mykhailo Braichevskyi Street and Koval'skyi Lane, there is no hot water supply due to a heating network break.
#  - Estimated return time, according to Kyivteploenergo: today by 20:00.
#  - @kpicampus
#  - 💧**May Without Water**
#
# In the dormitories, there is no hot water supply due to a heating network break and ongoing repair work until May 13 at 23:59.
#  - After their completion, hydraulic tests of the pipes will begin until the end of the month.
#  - Estimated completion date for all work and return of water, according to Kyivteploenergo: May 28 — 31.
#  - @kpicampus
#  - 💡**Power Outages**
#
# Starting from May 16, hourly power outages may occur in Kyiv and the student campus according to the [schedule](https://www.dtek-kem.com.ua/ua/shutdowns) of Ukrenergo and DTEK.
#  - Preliminary outages may occur [from](https://t.me/suspilnenews/32727) 00:00 to 9:00 or from 16:00 to 24:00.
#  - @kpicampus
#  - **🟢 Administration**
#
# **Shelters**
# Repairs are planned in 6 dormitories that have shelters by autumn.
#  - **Power Banks**
# For emergency charging, most dormitories have [power banks](https://t.me/ecokpi/142) available at the reception.
#  - If you do not have a power bank or it is in poor condition, write for a replacement to @kpicampus_bot.
#  - **Generators**
# Will only be used in case of power outages lasting more than 4 hours, and only for charging flashlights and phones.
#  - @kpicampus
#  - UPD: The hot water supply outage has been extended to June 10.
#  - @kpicampus
#  - 🟢  **Administration**
#
# **Accommodation**
# The accommodation algorithm for summer will be announced tomorrow, based on a similar, [last year's principle](https://t.me/kpicampus/1580).
#  - The number of accommodation places for the next academic year is planned to increase by 1.5 thousand.
#  - Instructions for accommodation will be available by July 17.
#  - **Elevators**
# Elevators are starting to resume operation, but you need to monitor the outage schedules to avoid getting stuck in the elevator in the middle of the night.
#  - @kpicampus
#  - 🏡  **Summer Accommodation**
#
# **The accommodation algorithm this year for students remains unchanged.
#  - You need to settle all debts, fill out a clearance form, and write a request for summer accommodation.
#  - The payment for the summer period this time will be 1600/1800, regardless of the number of residents in the room.
#  - New entrants pay according to [third-party tariffs](https://t.me/kpicampus/1053) and retain their place if they previously lived in the dormitory.
#  - After submitting documents for the master's/PhD program at KPI, applicants can submit confirming documents to reduce the amount and pay 1600/1800 UAH accordingly.
#  - To settle in, submit a request to the dormitory manager by June 21.
#  - **Examples of requests**:
# [• for students](https://docs.google.com/document/d/18Ih1pOeL3Jwd3HrYOX9VPMIYlFr9iuC8/edit?usp=sharing&ouid=107631616912058936796&rtpof=true&sd=true);
# [• for master's entrants](https://docs.google.com/document/d/1WiTAFG_VdgJwCL1MBtTQOJF-MsTYfr9a/edit?usp=sharing&ouid=107631616912058936796&rtpof=true&sd=true);
# [• for academic leave](https://docs.google.com/document/d/1rQ7il7UyCBvmys_7btfBAHesnCu56ahi/edit?usp=sharing&ouid=107631616912058936796&rtpof=true&sd=true).
#  - If you have questions, write to @kpicampus_bot.
#  - @kpicampus
#  - 🟢 **Administration 06.08**
#
# **Accommodation**
# Will start on August 26, and by the end of the week, there will be lists for accommodation from faculties and institutes.
#  - A total of about 9 thousand students are planned to be brought out for mixed learning.
#  - **Masters**
# By August 2, they should have written a [request](https://docs.google.com/document/d/13FJxmoUKzXYeRo9T8oGxshdi3MXm1faIDpQwAO6Tk1E/edit?usp=sharing) for a change in payment format and extension of residence in the dormitory until August 31.
#  - If you have not written a request, please contact the manager.
#  - **Hot Water**
# In some dormitories, there has been no hot water for 3 months due to major repair work.
#  - **Elevators**
# Due to the stabilization of electricity supply, the operation of most elevators will be restored.
#  - @kpicampus
#  - **🔑 Accommodation for Senior Students**
#
# Students of 2nd–4th year of bachelor's and 2nd year of master's programs who fall under priority categories can settle from **August 26** to **September 15** for the new academic year.
#  - If you are settling in for the first time — make sure to do it **by September 5**.
#  - First-year master's students will settle **from September 10 to 15**.
#  - 2.
#  - Follow the [accommodation algorithm](https://telegra.ph/Poselennya-studentstva-starshih-kurs%D1%96v-08-13#%D0%9D%D0%B5%D0%BE%D0%B1%D1%85%D1%96%D0%B4%D0%BD%D1%96-%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D0%B8).
#  - If you have questions, write to @kpicampus_bot.
#  - @kpicampus
#  - 🙌 **Volunteer Recruitment for Accommodation Assistance**
#
# We are looking for volunteers who are ready to help with the accommodation of newcomers!
#  - This is a great opportunity to meet new people and make the lives of first-year students in the campus easier.
#  - If you have some free time and want to do something useful – fill out the [form at the link](https://forms.gle/3i48ThrZcRTxM3e68) **by August 25 inclusive.
#  - ** We look forward to having you on our team!
#  - @kpicampus
#  - 🌡 **Hot Water Outage**
#
# Due to emergency work by Kyivteploenergo, there is no hot water in some dormitories.
#  - **
#
# Hot water supply is planned to be restored by the evening of August 29.
#  - @kpicampus
#  - 💧 **Water Outage**
#
# Due to emergency work by Kyivteploenergo, there may be interruptions in water supply in some dormitories.
#  - **
#
# Water supply is planned to be restored by 14:00 on September 16.
#  - @kpicampus
#  - 🚀 **Freshman Sprint**
#
# **KPI is not just about studying, but also about many opportunities for activity and development.
#  - **
#
# **On October 7**, come to **FIOT Hub, Building 18, KPI** to listen to lectures from members of the Student Council, teachers, and ["Tower"](https://t.me/vezhakpi).
#  - The event will last from **12:00 to 16:00**.
#  - We will talk about the importance of volunteer work, the pros and cons of living in a dormitory, socialization at the university, and much more.
#  - [Fill out the form](https://docs.google.com/forms/d/12_uKqU8qJgqhBimEnJCVPRwMlJqy_2xPnao6ZwJFPzw/edit) — get a chance to learn useful and interesting information 💙
#
# @sr_kpi
#  - 🌡️ **Heating Network Repairs**
#
# In some dormitories on Braichevskogo and Yangel streets, hot water supply is unavailable.
#  - According to Kyivteploenergo, the estimated time of return is tomorrow at 15:00.
#  - @kpicampus
#  - **🌡️ Repair Work on Heating Networks**
#
# Today from 9:00, hot water supply and heating are unavailable in most dormitories.
#  - Estimated time of return: 12:00 on November 12.
#  - @kpicampus
#  - 🚰 **Message from the Future**
#
# According to Kyivteploenergo, starting tomorrow at 9:00, water supply will be unavailable.
#  - The estimated time of return will be announced by Kyivteploenergo tomorrow, based on the volume of work.
#  - @kpicampus
#  - 🌡 **Room Temperature Water**
#
# According to Kyivteploenergo, there are problems with the circulation of hot water in the student campus, which is causing a decrease in water temperature in most dormitories.
#  - Currently, this situation has arisen in dormitories 8, 15, and 16.
#  - The estimated time of return today is by 18:00.
#  - @kpicampus
#  - ⚠️ **Emergency**
#
# Emergency power outage across the Shulyavka area and KPI.
#  - According to DTEK, the estimated time of return is 18:00.
#  - If you need to charge, approach the guards for a power bank.
#  - @kpicampus
#  - ☃️ **Heating Season Ended**
#
# Today marks the end of the heating season according to the [KMDA plan.
#  - ](https://t.me/KyivCityOfficial/9249)
#
# In the coming days, heating will be completely turned off in all dormitories.
#  - @kpicampus
#  - **💧Heating Network Emergency**
#
# In the dormitories on Oleksy Tykhyi and Borshchahivska streets, there is no hot water supply due to a heating network break.
#  - According to Kyivteploenergo, the estimated time of return is April 3 by 11:00.
#  - @kpicampus
#  - 💡**Power Outage**
#
# Starting May 16, hourly power outages may occur in Kyiv and the student campus according to the [schedule](https://www.dtek-kem.com.ua/ua/shutdowns) of Ukrenergo and DTEK.
#  - Preliminary outages may occur [from](https://t.me/suspilnenews/32727) 00:00 to 9:00 or from 16:00 to 24:00.
#  - @kpicampus
#  - **🟢 Administration**
#
# **Shelters**
# Repairs are planned in 6 dormitories that have shelters by autumn.
#  - **Power Banks**
# For emergency charging, most dormitories have [power banks](https://t.me/ecokpi/142) located at the reception.
#  - If you do not have a power bank or it is in poor condition, write about the replacement to @kpicampus_bot.
#  - **Generators**
# Will only be used in case of power outages longer than 4 hours, and only for charging flashlights and phones.
#  - @kpicampus
#  - UPD: The hot water supply outage has been extended to May 10.
#  - @kpicampus
#  - 🟢 **Administration**
#
# **Settlement**
# The settlement algorithm for summer will be announced tomorrow, based on a similar, [last year's principle](https://t.me/kpicampus/1580).
#  - The number of settlement places for the next academic year is planned to increase by 1.5 thousand.
#  - Instructions for the settlement itself will be available by July 17.
#  - **Elevators**
# Elevators are starting to resume operation, but you need to monitor the outage schedules to avoid getting stuck in the elevator in the middle of the night.
#  - @kpicampus
#  - **UPD*3: **According to information from** **Kyivteploenergo, the repair of the hot water supply has been extended to 23:00 today.
#  - Estimated time of return: tonight — tomorrow morning.
#  - @kpicampus
#  - 🌡️ **Well, you get it**
#
# **Kyivteploenergo promises every day to finish the work by 23:00, but "something" is going wrong.
#  - Estimated time: by the end of the month.
#  - Probably in 2024.
#  - @kpicampus
#  - 🟢 **Administration 06.08**
#
# **Settlement**
# Will begin on August 26, by the end of the week there will be lists for settlement from faculties and institutes.
#  - A total of about 9 thousand students are planned for mixed learning.
#  - **Masters**
# By August 2, they should have written a [request](https://docs.google.com/document/d/13FJxmoUKzXYeRo9T8oGxshdi3MXm1faIDpQwAO6Tk1E/edit?usp=sharing) for a change in payment format and extension of residence in the dormitory until August 31.
#  - If they did not write a request, they should contact the manager.
#  - **Hot Water**
# In some dormitories, there has been no hot water for 3 months due to major repair work.
#  - **Elevators**
# Due to the stabilization of electricity supply, the operation of most elevators will be restored.
#  - @kpicampus
#  - 🌡 **Hot Water Outage**
#
# **Due to emergency work by Kyivteploenergo, there is no hot water in some dormitories.
#  - **
#
# Hot water supply is planned to be restored by the evening of August 29.
#  - @kpicampus
#  - 💧 **Water Outage**
#
# **Due to emergency work by Kyivteploenergo, there may be interruptions in water supply in some dormitories.
#  - **
#
# Water supply is planned to be restored by 14:00 on September 16.
#  - @kpicampus
#  - The student campus of KPI named after Igor Sikorsky is conducting a survey among dormitory residents regarding "Preparing the population for national resistance".
#  - 📌 This is a one-day or five-day training course for KPI students, conducted by instructors from the training department as part of the project "Preparing the population for national resistance" at the locations of the State Educational Institution "KPK with enhanced military and physical training".
#  - ☘️ The course is free.
#  - The program includes training, field trips to the training ground, and a tactical medicine course.
#  - 🫂 The survey aims to assess the readiness of students for military-patriotic training.
#  - After analyzing the responses, the student campus will form groups of students.
#  - [Take the survey](https://docs.google.com/forms/d/e/1FAIpQLSeIe7nZPhIoxXZwAQ3NISn3BbvNph31yR26tf8SHlool-Q8iA/viewform)
#  - 🌡️ **Heating network repairs** Hot water supply is absent in some dormitories on Braichevskogo and Yangelya streets.
#  - According to Kyivteploenergo, the estimated time of return is tomorrow at 15:00.
#  - @kpicampus
#  - **Due to an emergency in the heating network in the Solomyansky district, repair work is being carried out.
#  - **⛔️💦 Hot water supply in the student campus will be unavailable until 13.10.23 (estimated restoration time by 23:00)
#  - 🔮 Legends say that once the SRG organized movie nights, so.. **Let's go watch a movie together!
#  - ** 🥳☺️ A pleasant company and soft poufs are guaranteed✨ ✅ When?
#  - 14.10.2023 at 21:30 ✅ Where?
#  - 7th floor hall P.S.
#  - Bring your favorite cup, we provide coffee and tea, you bring a good mood!🌞 🫖☕️ #movie_night
#  - **For students living in the student campus of KPI named after Igor Sikorsky, enrollment is announced for a training course on preparation for National Resistance**!
#  - 🔸 This week, starting from 23.10.2023, KPI students living in dormitories will begin a five-day course on the basics of tactical medicine, mine-explosive safety, and tactical training.
#  - This group of students is already the second; currently, recruitment for the third group is ongoing, which will start training on 30.10.2023.
#  - You can watch how it was [in the video.
#  - ](https://youtu.be/PRQ069-jT9A) 😉 Training will be held on a regular basis, and a new group of students will start every Monday.
#  - To join the next group – [register via the link](https://forms.gle/8TGFP8N8a3GWYKBc9) and the organizers will contact you, and join the group via the link: https://t.me/+99UnT86pbCk0MDgy.
#  - Upon completion of the course, you will definitely receive a certificate of completion.
#  - 📝 [Registration](https://forms.gle/8TGFP8N8a3GWYKBc9) 🕑 **When:** until October 29, 2023.
#  - [​​](https://telegra.ph/file/545af418e6783924e0fae.jpg)Who wants to visit the gym - join the [chat](https://t.me/+nwzGCFZhFZA3NTgy), register there using the pinned link.
#  - The mandatory condition for visiting the gym is: 1.
#  - Register 2.
#  - Take turns according to the schedule.
#  - [​​](https://telegra.ph/file/4f31281343d9f30ec67da.jpg)🎃👻 HURRY TO SAVE YOURSELF!
#  - 👻🎃 Halloween is the time when evil spirits come out of control!
#  - But we know how to fight them!
#  - 🛡 Our neomolfars are true professionals in the protection against mermaids, vampires, and werewolves.
#  - What we offer: 🛡 Protection from evil forces all night from 31.10 to 01.11; 🔮 Magical amulets that will protect you and your neighbors; 🪄 Trials, upon successful completion of which you will receive honor, glory, and long-awaited protection.
#  - Enjoy terrifying Halloween adventures without worrying about your safety!
#  - Fill out the [form](https://forms.gle/qGBqfqbNZnhuGNw38) and book your protectors right now!
#  - 📝🔮 🌙 Date and time of the ritual: evening of October 31 📍 Location: in your room!
#  - Fill out the [form](https://forms.gle/qGBqfqbNZnhuGNw38) to order the service of neomolfars:
#  - [​​](https://telegra.ph/file/5e53a99ee3b59fc908e6f.jpg)🎃👻 Halloween is coming soon!
#  - 🎃👻 🟠 Hurry up and fill out the [Google form](https://forms.gle/qGBqfqbNZnhuGNw38) if you want your room to be protected from monsters on the night of October 31 to November 1.
#  - 🔵 To receive protection, you need to pass a small trial from our neomolfars (the trial will take about 5-10 minutes).
#  - 🟡 In the [Google form](https://forms.gle/qGBqfqbNZnhuGNw38), indicate your preferred time for the visit to your room (but keep in mind that neomolfars may come a little earlier or later, depending on how the trials of other participants go).
#  - 🟣 Not everyone will be able to receive the desired protection, so be attentive and brave when the neomolfars visit you!
#  - Hey, everyone!
#  - 🎲 Shall we play board games in the dormitory?
#  - We are sure we will have a great time together!
#  - And whoever wins the most will receive gifts!
#  - 🤩 🕹 Want to play?
#  - Click the survey⬇️
#  - **Residents of the left room of block 13 from floors 2-12!
#  - **Tomorrow (21.11.2023) please clear access to the heating radiator (move tables, chairs, nightstands....).
#  - Plumbing work will begin at 10:00.
#  - ** **__Administration of dormitory 18.__
#  - [❤️](https://telegra.ph/file/f4df71ea778c26eea6a46.png)** Donor Day at KPI**__ **▫️** We invite you to join the traditional Donor Day at KPI for the benefit of the Kyiv City Blood Center, from where your blood will be delivered to those who need it most.
#  - ▫️ What is needed for a successful donation: • be over 18 years old (inclusive) and weigh over 55 kg; • familiarize yourself with [temporary](https://www.donor.ua/pages/5) and [absolute](https://www.donor.ua/pages/4) contraindications to donation; • follow the [donor diet;](http://kmck.kiev.ua/pidgotovka-donora/) • definitely have breakfast in the morning; • bring your passport.
#  - 💪 Together we can move this world from a hopeless point!
#  - **📝 **[Registration is mandatory!
#  - ](https://forms.gle/bxVuuyFTaKH9agr97) The number of places is limited.
#  - [ ](https://docs.google.com/forms/d/e/1FAIpQLSd1iF25BH7wegj9Hy8ccZk-0HqRanGgE2PqVKFDVI6UKMMSeQ/viewform)🕑 **When: **November 27 (Mon) from 9:30 to 13:00.
#  - 📍**Where:** [Social Service premises,](https://www.google.com/maps/dir//%D1%81%D1%82%D1%83%D0%B4%D0%B5%D0%BD%D1%82%D1%81%D1%8C%D0%BA%D0%B0+%D1%81%D0%BE%D1%86%D1%96%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0+%D1%81%D0%BB%D1%83%D0%B6%D0%B0/@50.4502198,30.4465351,16z/data=!4m8!4m7!1m0!1m5!1m1!1s0x40d4cd564e305e37:0x83e252d0bb8a4977!2m2!1d30.4507936!2d50.4465434) 144 Borshchahivska St. (dormitory 20, entrance on the left).
#  - In case of an air raid, you can use the nearest [shelter](https://t.me/dnvr_31/1893).
#  - [💭](https://goo.gl/maps/taEFpY5fVE51okgi8) Social Service on [telegram](http://t.me/sss_kpi) | [instagram](http://instagram.com/sss.ntuu.kpi) | [youtube.
#  - ](https://www.youtube.com/channel/UCZKbCSXqkSHDKUC4S0u-6xg) Feedback: @ask_sss_bot #DNVR #student_social_service
#  - 🥇 **Board games** **Were you waiting?
#  - Let's spend the evening in a friendly atmosphere!
#  - 🥳 🎁 You will be able to play exciting games and receive exclusive **gifts** for your achievements!
#  - ✅ When?
#  - 25.11.2023 at 18:30 ✅ Where?
#  - In our dormitory __(details later)__ P.S.
#  - Bring your favorite cup, and we will treat you to delicious tea and cookies!
#  - ☕️🍪 To participate – fill out the [form](https://forms.gle/U4ppSmrkhRmFYBj49)
#  - **Board game evening (25.11) - done✅** **Bright impressions and positive emotions - received✅** We express our sincere gratitude to our partners for the wonderful prizes!
#  - **🍕Our Bakery of Capital Traditions:** Thank you for the incredibly delicious cookies that filled our evening with warmth and flavor!
#  - __P.S.
#  - When buying two pizzas, the third one is free.__ [Borshchahivska St., 128](https://maps.app.goo.gl/W6umedExeY4cRYB76) **🎲 **[**Geekach:**](https://geekach.com.ua/) Thank you for the board games that, uniting us, became the foundation of our event.
#  - **💃 **[**KPI Trade Union:**](https://t.me/pskpi) Thanks for the warm tea and gifts that became wonderful rewards for the participants of the evening.
#  - **🫔 **[**BigMama:**](https://www.instagram.com/big.mama.plth/?utm_source=ig_web_button_share_sheet&igshid=OGQ5ZDc2ODk2ZA==) Gratitude for the certificates for delicious rolls received by our winners.
#  - **28.11.23, 16:30, Dormitory No.
#  - 3, Director's office** A meeting of the director of the student campus with the **student activists of the dormitories will take place!
#  - ** **We invite the heads of student councils and socially active students!
#  - **
#  - **Residents of the left room of block 11 from floors 2-12!
#  - **Tomorrow (05.12.2023) please clear access to the heating radiator (move tables, chairs, nightstands....).
#  - Move the beds 1 meter away from the radiator.
#  - Plumbing work will begin at 10:00.
#  - ** **__Administration of dormitory 18.__
#  - 🤖 **At night on mobile** From 23:00 to 6:00, KPI Telecom will turn off the internet due to scheduled maintenance work.
#  - @kpicampus
#  - ⚡️⚡️⚡️Power outage due to emergency cable damage, operational replacement will be carried out and they promise to turn it on soon.
#  - According to DTEK.
#  - 🏰 During the hard battles with studying and homework, our dormitory becomes a fortress, and we are true knights in the fight against routine days.
#  - We invite you to a movie screening within the walls of 18!
#  - Tomorrow, November 10, interesting films await you, popcorn from the Trade Union, hot drinks, and delicious cookies from "Our Bakery of Capital Traditions".
#  - **When:** 18:00 **Where:** 7th floor hall.
#  - 🎥 We will start with the screening of "Sniper.
#  - The White Crow".
#  - This is not only an exciting story but also a reflection of our reality.
#  - After the first film, there will be a break during which you can discuss impressions and share emotions with other participants.
#  - 🎬 At 20:30, the screening of the Ukrainian historical drama "Shchedryk" will start.
#  - Is it possible to reconcile the world with the melody of "Shchedryk"?
#  - Taking this opportunity, we urge you to help the Armed Forces.
#  - Let's support the collection of the [Trade Union](https://t.me/pskpi) for the preparation of quarter-wave antennas for radios, which increase the reception radius by 30%.
#  - 🔗 Link to the bank: https://send.monobank.ua/jar/51U8iZJtvg P.S.
#  - : __bring your favorite cups, neighbors, and a good mood!__
#  - **Attention!
#  - ** Water pipe break on Oleksy Tykhyi Street.
#  - There may be a water outage in the student campus!
#  - **
#  - [​​](https://telegra.ph/file/bfcb1019f997112c98155.jpg)🎥 The movie screening is in the past, so it's time to sum up!
#  - On December 10, within the walls of 18, the screenings of the films "Sniper.
#  - The White Crow" and "Shchedryk" took place.
#  - We express our sincere gratitude to our partners: 🍪 Thank you to ["Our Bakery of Capital Traditions"](https://maps.app.goo.gl/W6umedExeY4cRYB76) for the extraordinarily delicious cookies that made the movie screening even more unforgettable!
#  - 🍿 We are grateful to [KPI Trade Union](https://t.me/pskpi) for the popcorn that provided our evening with a special atmosphere.
#  - Also, we appreciate your opinion regarding future events and are always looking forward to suggestions and wishes.
#  - ❤️ Thank you for being with us!
#  - Friends, thanks to you, an extraordinarily large amount has been raised for heating pads for our military, and @rud_dash immediately purchased the materials.
#  - Production will start on Monday.
#  - There are enough materials for 750 HEATING PADS, which is a heavy load for one person, Dasha WILL NOT MANAGE WITHOUT YOUR HELP.
#  - On Friday, she is going to Kharkiv to meet with the military and hand them the heating pads so they can start warming the guys as soon as possible.
#  - Therefore, in 4 days, we need to make as many as possible.
#  - After her return, she will also be making heating pads, so if you can't make it now, still write!
#  - We kindly ask you - maybe someone wants to join our small company, take a break from studying, and socialize with new people.
#  - It's not necessary to come for all 4 days.
#  - The production of heating pads will be in the evenings.
#  - Write to @rud_dash, she will add you to the chat.
#  - Wishing everyone peace and inspiration!
#  - **Dear 6th-year students, please note that you have 14 days to vacate the dormitory after graduation from the university.
#  - You must vacate by 14.02.2024.
#  - We want to emphasize that payment for accommodation during this period from 01.02.2024 will be at the rates for outsiders, which are: 4-bed - 1630 UAH per month 3-bed - 2117 UAH per month 2-bed - 3092 UAH per month 1-bed - 6016 UAH per month.
#  - ** Administration of dormitory 18.
#  - Dear residents of the student campus, students, and university staff!
#  - Currently, mesh-type containers have been installed in nine locations on the campus for temporary waste storage.
#  - Sincerely, the university administration!
#  - ELECTRICITY SUPPLY: The student campus is investigating the cause of the outage and the preliminary timeline for restoration.
#  - If it is not restored by 17:00, we will start the generator in the trade union office, and we will inform you additionally.
#  - Missing the outages?
#  - ⚠️ **Emergency** An emergency power outage is occurring throughout the Shulyavka area and KPI.
#  - The estimated time for restoration, according to DTEK, is 18:00.
#  - If you need to charge your devices, please approach the security for a power bank.
#  - @kpicampus
#  - **Goodbye winter, hello spring🌷** We invite you to a delicious and vibrant **Maslenitsa 2024** in the best traditions of KPI!
#  - **On March 17 at 12:00**, come to the spring celebration of pancakes, games, and charity.
#  - This year, the student councils of KPI have united, so the event will be more massive than ever!
#  - Fill out the [registration form](https://forms.gle/1jf1ypnxnsFxrA188) to be heard and seen!
#  - The percentage to donate to the Armed Forces of Ukraine is up to each individual.
#  - We are waiting for you [at the link](https://forms.gle/3nEB77ufWgSACrok7)!
#  - Become a part of this extraordinary event and support the charity fair!
#  - **See you at Maslenitsa 2024** 🥞 [Student Council of the Faculty of Physics and Technology 💙](https://t.me/students_ipt)
#  - 🎬 We invite you to watch a selection of films about the stories of women's struggle and victory in various fields of life!
#  - **When: March 9 at 19:30** Where: **7th floor hall** 🧪 At **19:30**, the science fiction thriller **"Dangerous Element"** will start.
#  - The film tells the story of the life, love, and scientific achievements of one of the most talented women scientists – Marie Curie, the first female Nobel Prize laureate.
#  - 💃 At **21:00**, the American comedy-drama **"The Devil Wears Prada"** will be shown, which tells the story of a young woman working at a powerful magazine but facing difficulties while collaborating with a tough editor.
#  - P.S.
#  - : **bring snacks, neighbors, and a good mood!
#  - **
#  - Attention!!
#  - !
#  - Due to repair work, the elevators will not be operational from 10:00 to 15:00.
#  - Administration of dormitory 18.
#  - Pancake for a donation 🥞 Today, together with other student councils, we held a large fair and concert.
#  - Around 18:00, **we invite residents of dormitory 18 to the kitchen on the 4th floor (blocks 1-10) to have dinner with delicious pancakes for a donation**!
#  - Hurry to enjoy the taste of Maslenitsa ✨ [Representatives of the Student Council of the Faculty of Physics and Technology of dormitory 18 💙](https://t.me/students_ipt)
#  - **VOLUNTEERING** We need people tomorrow to collect food packages (packing products into boxes, gathering boxes, sticking labels) for frontline areas.
#  - We start at 11:00, work will take no more than 5 hours (metro station Boryspilska).
#  - If you can go, please message @ogysuperpol, and I will add you to the chat.
#  - **VOLUNTEERING** March 30, Saturday 📦 We need people again to collect food packages (packing products into boxes, gathering boxes, sticking labels) for frontline areas (metro station Boryspilska).
#  - Departure from Polyana at 10:00, work will take no more than 5 hours.
#  - We will be fed 😋 If you can join, please fill out the [form](https://forms.gle/CWwhHChX7mUgxeG56) (there is a [contact for questions](http://t.me/ogysuperpol)).
#  - ☃️ **Heating has ended** Today marks the end of the heating season according to the [KMDA plan.
#  - ](https://t.me/KyivCityOfficial/9249) Over the next few days, heating will be completely turned off in all dormitories.
#  - @kpicampus
#  - **Heating network emergency.
#  - ** 😢😢😢 Hot water will be unavailable in dormitories No.
#  - : **16, 17, 18, 19, 20, 21**.
#  - Specialists from Kyivteploenergo are working to eliminate the consequences of the emergency, and restoration is possible within a day.
#  - **💧Heating network emergency** Hot water supply is absent in the dormitories on Oleksy Tykhyi and Borshchahivska streets due to a heating network break.
#  - The estimated time for restoration, according to Kyivteploenergo: April 3 by 11:00.
#  - @kpicampus
#  - ⚡️⚡️⚡️ Update on hot water.
#  - **The heating network emergency continues.
#  - ** 😢😢😢 Hot water will be unavailable in dormitories No.
#  - : **16, 17, 18, 19, 20, 21, 8, 12, 4**.
#  - Specialists from Kyivteploenergo are working to eliminate the consequences of the emergency, and they promise to restore water supply on Thursday during the day.
#  - Hot water supply has been restored!
#  - 🥵💦
#  - ⚽️ We invite everyone to watch the football broadcast at the [Trade Union](https://t.me/pskpi) of students ([__Borshchahivska 144a__](https://maps.app.goo.gl/xBwUAC3b7vZBLEAC9)).
#  - Start at **22:00**.
#  - 🔊 The administration would like to draw your attention to the fact that **playing loud music is considered a serious violation**, which may result in the termination of the accommodation agreement in the dormitory.
#  - There have already been evictions for this reason.
#  - If you are disturbed, please contact the DB at the number on the back of your pass or @ogysuperpol, and you can provide direct evidence of violations (photos/videos) to the dormitory administration directly.
#  - **Elections for the Chair of the Student Council of the FEA 👨‍🎓** Do you want to nominate yourself?
#  - Then fill out the preliminary registration form (deadline **April 22 at 20:00**).
#  - The procedure for approving a candidate: 1.
#  - Preliminary registration 2.
#  - Writing a resume 3.
#  - Collecting signatures 4.
#  - Filling out the candidate's application 5.
#  - Presenting an election program at the KSF.
#  - The head of the election commission of the FEA @vallimarkk will assist with this process and the execution of all points.
#  - Link for preliminary registration of candidates👇 https://forms.gle/NJEtqpKTeHVz19Am7
#  - The elections for the head of the Student Council of the FEA are approaching, and this is a time for all of us to show activity and influence the life of our faculty.
#  - Each of us has unique ideas and plans that can make our student community even better and more active.
#  - So we encourage each of you to consider running for the position of head of the Student Council of the FEA!
#  - **Write**: @vallimarkk Or **register**: https://forms.gle/NJEtqpKTeHVz19Am7 __💪🏻 Let's create an FEA together where every student can unlock their potential and achieve success!__
#  - 💦 Regarding hot water: "__Scheduled work has begun on the pipeline, estimated time - **until May 13** (inclusive)__" - Housing and Communal Services.
#  - 🤩 **Eurovision in the dormitory** Tomorrow, **May 7**, the __first semi-final of the Eurovision Song Contest 2024__ will take place.
#  - We invite you to join us for the viewing in the cozy company of dormitory residents!
#  - Don’t forget to bring snacks and drinks!
#  - The duo __Alyona Alyona and Jerry Heil__ will perform under number 5, so be sure to come and listen to their performance!
#  - We will be waiting for you!
#  - P.S.
#  - Don’t forget to bring chairs 🪑 **Where**: 7th floor hall **When**: 22:00
#  - Regarding hot water: ✅ Currently, repair work is ongoing at the CHPP that supplies hot water to the student campus; due to these circumstances, hot water supply is unavailable.
#  - ✅ From May 14, 2024, to May 28, 2024, hydraulic tests of the heating networks will be conducted.
#  - During this period, hot water supply will also be unavailable 😔
#  - 💧**May without water** Hot water supply is absent in the dormitories due to a heating network break and corresponding repair work until May 13 at 23:59.
#  - After their completion, hydraulic tests of the pipes will begin until the end of the month.
#  - The estimated completion date for all work and return of water, according to Kyivteploenergo: May 28 – 31.
#  - 📺**Watching the Eurovision final at the Trade Union (partially)** We invite those interested tomorrow to the broadcast of the main musical event of the year at the student trade union.
#  - We will watch there until 23:50, and then we will transfer the equipment for further broadcasting to the dormitory with the most attendees, with the possibility of further showing in the dormitory, in the working room.
#  - To understand the interest in the dormitories - please like the dormitory numbers ([in the comments](https://t.me/qappos) to this post)👇
#  - We invite you to join the viewing of the Eurovision 2024 final!
#  - The poufs are honestly won at the [Trade Union](https://t.me/pskpi) **Where**: 7th floor **When**: 22:00
#  - Attention!!
#  - !
#  - From 9:30 to 10:00, the water will be turned off.
#  - Repair work will be carried out.
#  - Approximately until 15:00-16:00.
#  - Administration of dormitory 18.
#  - 💡**Power outage** Starting from May 16, hourly power outages may occur in Kyiv and the student campus according to the [schedule](https://www.dtek-kem.com.ua/ua/shutdowns) of Ukrenergo and DTEK.
#  - Preliminary outages may occur from 00:00 to 9:00 or from 16:00 to 24:00.
#  - @kpicampus
#  - ⚡️⚡️⚡️**ATTENTION**⚡️⚡️⚡️ Due to **emergency power outages (not according to the schedule)**, there have been increased cases of people being trapped in elevators.
#  - Emergency crews are unable to quickly rescue people from traps.
#  - Therefore, it has been decided to **turn off the elevators until stabilization schedules for power outages are introduced.
#  - ** Thank you for your understanding ❤️
#  - Tomorrow (Monday), there will likely be a **power outage from 18:00 to 22:00**, according to the power outage schedule and the message from [Ukrenergo](https://t.me/Ukrenergo/2851).
#  - **🟢 Administration**
#
# **Shelters**
# Repairs are planned in 6 dormitories that have shelters by autumn.
#  - **Power Banks**
# For emergency charging, most dormitories have [power banks](https://t.me/ecokpi/142) available at the reception.
#  - If you do not have a power bank or it is in poor condition, please request a replacement via @kpicampus_bot.
#  - **Generators**
# Will only be used in case of power outages lasting longer than 4 hours, and only for charging flashlights and phones.
#  - @kpicampus
#  - 🔥🔥🔥Only 3 days left!
#  - 🔥🔥🔥
# **On 24.05.24, we invite you to "POLYANA FEST"!!
#  - !
#  - **🕺🏻🤸🏻‍♂️🎸🎡🍭🍹🌮🌭
# Spend your Friday in a useful and interesting way!
#  - We are sure that everyone will find something interesting to do and enjoy, and you will also contribute to a good cause.
#  - Donations collected at the festival will be transferred to [Charitable Foundation "Support of the Armed Forces of Ukraine 'Kyiv Polytechnic'"](https://t.me/kpifond), which supports KPI students defending Ukraine!
#  - ✌️✌️✌️Exciting and delicious locations await you!
#  - [REGISTER HERE](https://docs.google.com/forms/d/e/1FAIpQLSdNZca8P9nULbtM3TlKWerz0llK4NOcKeEy2mkOh9v_XqOE2w/viewform) ** and you will have SPORTS!
#  - 🎹**CONCERT** of invited guests and an open mic for those who wish.
#  - [REGISTER HERE](https://docs.google.com/forms/d/e/1FAIpQLSebXAbpMPoMSEED4CZC_WLVgJXnT-PAYuAo2eeN7JuuI2JP-g/viewform) and you will have GLORY!
#  - 🍩🥤**FOOD COURT:** Treats from the best chefs of the Student Campus and partners.
#  - We will also have real barbecue and refreshing drinks!
#  - ❤️ Bring your friends, neighbors, teachers, and come!
#  - 🕓**When: 24.05.2024 from 15:00 to 20:00**
# 📍**Where: Square of Building No.
#  - 12, "Polyana" Park.
#  - **
#  - UPD: The hot water supply shutdown has been extended until June 10.
#  - @kpicampus
#  - 🟢 **Administration**
#
# **Accommodation**
# The accommodation algorithm for the summer will be announced tomorrow, based on a similar, [last year's principle](https://t.me/kpicampus/1580).
#  - The number of accommodation places for the next academic year is planned to increase by 1,500.
#  - Instructions for accommodation will be available by July 17.
#  - **Elevators**
# Elevators are starting to resume operation, but it is necessary to monitor the outage schedules to avoid getting stuck in the elevator in the middle of the night.
#  - @kpicampus
#  - According to Kyivteploenergo, the hot water shutdown has been postponed to June 17...😢😢😢
#  - ‼️ **Debates of candidates for the position of rector of KPI**
#
# Candidates who made it to the second round of elections will participate in the debates: Anatoliy Melnychenko and Oleksiy Zhuchenko.
#  - Everyone interested will be able to watch the online broadcast.
#  - **Proposed topics for discussion:**
# 🔹 paths and prospects for the development of the university;
# 🔹 vision of personnel policy at the university;
# 🔹 functioning of various areas of the university's activities.
#  - ⏰ **When:** June 14 at 15:00
# 📌 **Where:** [online broadcast on KPI Media](https://youtube.com/live/jPCLBt9x6Kg?feature=share)
#  - **🍸 Bachelor Party is coming…**
#
# Tired of thinking about studying for hours?
#  - The exam session is almost over, so it's time to think a little about yourself.
#  - Time to relax, party, and unwind!
#  - We invite everyone to the **Bachelor Party**, organized in honor of the end of the semester.
#  - Forget about power outages, they won't stop us from having a great time!
#  - What awaits you:
# • A closed party in the style of the 2000s for KPI students and their friends
# • A bar with a student menu
# • Charity auctions, raffles, and beer pong
# • Vibe music from a DJ
#
# **When and where?
#  - **
# June 27, from 18:00 to 23:00
# [Forsage Dance Club, 51A Harnytnaya St.](https://maps.app.goo.gl/5qgPnR5j9pyYZnV86)
#
# **Theme:**
# American style, 2000s party
#
# Entry **only with flyers**.
#  - They can be [purchased online](https://forms.gle/B1VZn1AdJy5kik6UA) for 150 UAH and picked up at the KPI Student Committee or at the club entrance (read more in the form).
#  - At the party, go to the bar and exchange the flyer for one free cocktail "Sportcomplex" 🍹
#
# Bring your friends, come to the party, and together create the brightest memories of this summer ✨
#
# [Student Council of the Faculty of Physics and Technology 💙](https://t.me/students_ipt)
#  - UPD*3: According to **Kyivteploenergo**, the repair of the hot water supply has been extended until 23:00 today.
#  - Estimated return time: tonight — tomorrow morning.
#  - @kpicampus
#  - ✋**Greetings, dear community!
#  - **
#
# Following the beautiful saying of Napoleon Bonaparte...
# Who does not wish to feed their own army will soon feed someone else's...
# ...we have decided to create a **military-technical association at KPI that will do ✨interesting things✨**
#
# **Who do we need?
#  - ** Everyone.
#  - Really, everyone.
#  - If you want and can, we are waiting for you!
# ...
#  - **
#
# Therefore, the replacement of windows in the dormitories is postponed indefinitely.
#  - **Flood**
# **On Friday, the basement of dormitory 10 was flooded due to a pipe malfunction.
#  - **
#
# @kpicampus
#  - Hello everyone🎃
#
# We remind you that tomorrow in our dormitory there will be a quest and a costume contest👻
#
# Prizes:
# 1st place - 2 tickets to the fear room on Khreshchatyk;
# 2nd place - craft mulled wine;
# 3rd place - 2 pizzas;
# 4th place - work off (4 months);
# 5th place - 2 keychains "Hero of the Glade";
# 6th place - 2 raincoats.
#  - Register, the number of places is limited😉👇
#
# https://docs.google.com/forms/d/1ZkQ8TUFlVYIoFa9u_dnnnXeXZumYc6-XeFhcY5Zayn0/viewform?ts=6536495c&edit_requested=true
#  - 🌡️ **Repair Work on Heating Networks**
#
# Today from 9:00, there is no hot water supply and heating in most dormitories.
#  - Estimated return time: 12:00 on November 12.
#  - @kpicampus
#  - Hello everyone!
#  - Very soon, we want to hold a musical evening in our dormitory ♥️🎶
#
# We know that many talented people live here, so anyone who can play any musical instruments or sing and wants to perform and help us is welcome🫂
# (Write "+" to @Andrewkrulko)
#
# **P.S.
#  - For help, we will close 4 months of work off🥰**
#
# With love, student council🤍!
#  - 🤖 **At Night on Mobile**
#
# From 23:00 to 6:00, KPI Telecom will turn off the internet due to scheduled technical work.
#  - @kpicampus
#  - 🚰 **Message from the Future**
#
# According to Kyivteploenergo, starting tomorrow at 9:00, there will be no water supply.
#  - The estimated return time will be communicated by Kyivteploenergo tomorrow, based on the volume of work.
#  - @kpicampus
#  - ⚠️ **Emergency**
#
# Emergency power outage across the Shulyavka district and KPI.
#  - Estimated return time according to DTEK is 18:00.
#  - If you need to recharge, approach the guards for a power bank.
#  - @kpicampus
#  - Hello everyone☀️
#
# We invite you **tomorrow at 21:45 to the first working room** for a football match viewing⚽️
#
# We will be waiting for you😉
#
# With love, student council♥️!
#  - ☃️ **Heating Season Ended**
#
# Today marks the end of the heating season according to the [KMDA plan.
#  - ](https://t.me/KyivCityOfficial/9249)
#
# In the coming days, heating will be completely turned off in all dormitories.
#  - @kpicampus
#  - **💧Emergency on Heating Networks**
#
# In the dormitories on Oleksy Tykhyi and Borshchahivska streets, there is no hot water supply due to a heating network break.
#  - Estimated return time, according to Kyivteploenergo: April 3 by 11:00.
#  - @kpicampus
#  - 💧**May Without Water**
#
# In the dormitories, there is no hot water supply due to a heating network break and ongoing repair work until May 13 at 23:59.
#  - After their completion, hydraulic tests of the pipes will begin until the end of the month.
#  - The estimated completion date for all work and return of water, according to Kyivteploenergo: May 28 - 31.
#  - @kpicampus
#  - 💡**Power Outages**
#
# Starting May 16, hourly power outages are possible in Kyiv and the student campus according to the [schedule](https://www.dtek-kem.com.ua/ua/shutdowns) of Ukrenergo and DTEK.
#  - Preliminary outages are possible [from](https://t.me/suspilnenews/32727) 00:00 to 9:00 or from 16:00 to 24:00.
#  - @kpicampus
#  - ⚡️**Power Outage Schedules for the Dormitory**
#
# On May 17, outages will only occur from 00:00 to 8:00 and from 19:00 to 00:00.
#  - Black lightning - no power.
#  - Gray lightning - 50/50.
#  - No lightning - power is on (in the absence of emergency outages).
#  - The elevator is not working due to the outage, so you won't get stuck there.
#  - Hot water is promised to return in June.
#  - UPD: The hot water supply outage has been extended to May 10.
#  - @kpicampus
#  - 🟢 **Administration**
#
# **Accommodation**
# The accommodation algorithm for the summer will be tomorrow, based on a similar, [last year's principle](https://t.me/kpicampus/1580).
#  - The number of accommodation places for the next academic year is planned to increase by 1.5 thousand.
#  - Instructions for accommodation will appear by July 17.
#  - **Elevators**
# Elevators will begin to resume operation, but you need to monitor the outage schedules to avoid getting stuck in the elevator in the middle of the night.
#  - @kpicampus
#  - 🔥Hello dear residents of #20🔥
#
# This **Saturday, June 22, 2024, in the yard of our dormitory**, we invite you to celebrate the Kupala holiday, as well as the day of #20!
#  - 🌺You will find:
#
# - Charity fair
# - Raffle of 2 exclusive t-shirts
# - Kupala entertainment
# - Homemade kvass and other treats
# - Good mood
#
# With love, student council!♥️
#
# With the support of the student trade union 💙
#
# We are collecting for👇
# **The unit of students from FSP, ORVP "Blind Fury" UDA** needs your help.
#  - https://www.instagram.com/blind.fury.official?igsh=MWJmd2ozdno4MnY1Zw==
#  - 🌡️ **Well, you got it**
#
# **Kyivteploenergo promises every day to finish the work by 23:00, but "something" is going off plan.
#  - **
#
# Estimated time: by the end of the month.
#  - Probably in 2024.
#  - @kpicampus
#  - Dear friends!
#  - I inform you that by the order of the Minister of Education and Science, as of today, July 19, 2024, **I have been appointed as the rector of KPI Igor Sikorsky.
#  - **
#
# **Thank you for your trust!
#  - **
# I understand the responsibility I am taking on and will begin to implement the points of the program with which I ran for election.
#  - **The urgent tasks** now are the successful conduct of the admission campaign, ensuring the stability of the university's operation, and, most importantly, concentrating efforts to strengthen the defense capability of the state.
#  - I will inform you about further steps on the [channel](https://t.me/melnychenko2024) and the official resources of the university.
#  - 🟢 **Administration 06.08**
#
# **Accommodation**
# Will begin on August 26, by the end of the week there will be lists for accommodation from faculties and institutes.
#  - A total of about 9 thousand students are planned to be brought out for mixed learning.
#  - **Masters**
# By August 2, they should have written a [request](https://docs.google.com/document/d/13FJxmoUKzXYeRo9T8oGxshdi3MXm1faIDpQwAO6Tk1E/edit?usp=sharing) for a change of payment format and extension of residence in the dormitory until August 31.
#  - If you haven't written a request, please contact the head of the dormitory.
#  - **Hot Water**
# In some dormitories, there has been no hot water for 3 months due to major repair work.
#  - **Elevators**
# Due to the stabilization of electricity supply, the operation of most elevators will be restored.
#  - @kpicampus
#  - In some dormitories of the Student Campus, there is no hot water supply.
#  - ⚡️⚡️⚡️Reason: emergency work by KYIYENERGO.
#  - ✅Restoration is expected on 29.08.24 approximately from 13:00.
#  - 🟢**Administration
#
# Points of Resilience
# **Points of resilience will be located in working rooms 9, 13, and 14 of the dormitories.
#  - They promise to organize points in each dormitory where there is shelter and a working generator.
#  - **Heating
# **It will gradually appear in the student campus by the end of the week.
#  - **Windows
# **The student campus purchased windows through a tender to insulate the dormitories, but during installation, it turned out that the specifications indicated windows of the wrong size.
#  - Therefore, the replacement of windows in the dormitories is postponed indefinitely.
#  - **Flood
# **On Friday, the basement of dormitory 10 was flooded due to a pipe malfunction.
#  - @kpicampus
#  - 🏘 **Masters Graduating**
#
# At the last housing council meeting, it was decided that master's students who are graduating must vacate the dormitory within two weeks from the date of graduation.
#  - To continue living, these individuals will need to write an additional application to the dormitory manager and attach supporting documents.
#  - @kpicampus
#  - ☃️ **New Year Celebration**
#
# During the celebration, please remember that pyrotechnics, garlands, heaters, and electric stoves are prohibited.
#  - On the territory of the Student Campus, all of the above, even on New Year's Eve, [is a violation of the agreement](https://drive.google.com/file/d/1-8FNH6XMiaM3cjy9v8fcCykJHuFxRDXZ/view?usp=sharing) at your own risk.
#  - Also, do not ignore air raid signals and go to the shelter.
#  - @kpicampus
#  - 🟢 **Administration 06.08**
#
# **Housing**
# Will begin on August 26, and by the end of the week, there will be lists for housing from faculties and institutes.
#  - In total, about 9,000 students are planned to be accommodated for mixed learning.
#  - **Masters**
# By August 2, they were supposed to write a [request](https://docs.google.com/document/d/13FJxmoUKzXYeRo9T8oGxshdi3MXm1faIDpQwAO6Tk1E/edit?usp=sharing) for a change in payment format and an extension of residence in the dormitory until August 31.
#  - If you did not write a request, please contact the head of the dormitory.
#  - **Hot Water**
# In some dormitories, there has been no hot water for 3 months due to major repair work.
#  - **Elevators**
# Due to the stabilization of electricity supply, the operation of most elevators will be restored.
#  - @kpicampus
#  - 🔑 **Housing for Senior Students**
#
# Students of 2nd to 4th year of bachelor's degree and 2nd year of master's degree who fall under priority categories can move in from **August 26** to **September 15** for the new academic year.
#  - If you are moving in for the first time, make sure to do it **by September 5.
#  - **
#
# First-year master's students will move in **from September 10 to 15**.
#  - 2.
#  - Follow the [housing algorithm](https://telegra.ph/Poselennya-studentstva-starshih-kurs%D1%96v-08-13#%D0%9D%D0%B5%D0%BE%D0%B1%D1%85%D1%96%D0%B4%D0%BD%D1%96-%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D0%B8).
#  - If you have questions, write to @kpicampus_bot
#
# @kpicampus
#  - 🙌 **Recruitment of Volunteers for Housing Assistance**
#
# We are looking for volunteers who are ready to help with the accommodation of newcomers!
#  - This is a great opportunity to meet new people and make the lives of first-year students in the student campus easier.
#  - If you have some free time and want to do something useful – fill out the [form at the link](https://forms.gle/3i48ThrZcRTxM3e68) **by August 25 inclusive.
#  - ** We look forward to having you on our team!
#  - @kpicampus
#  - 🌡 **Hot Water Shutdown**
#
# Due to emergency work by Kyivteploenergo, there is no hot water in some dormitories.
#  - **
#
# Hot water supply is planned to be restored by the evening of August 29.
#  - @kpicampus
#
# Cluster 3:
#  - Have questions or suggestions?
#  - The debates will take place without spectators and guests.
#
# Cluster 1:
#  - **Inventory**
# From June 5 to June 7, an inventory commission will check the current state of inventory in the rooms.
#  - **Inventory**
# From June 5 to 7, an inventory commission will check the current state of inventory in the rooms.
#  - **Priority Categories:**
# 1.
#  - Those who are on the [lists of in-person disciplines](https://t.me/sr_kpi/4925).
#  - **Inventory**
# From June 5 to 7, an inventory commission will check the current state of inventory in the rooms.
#  - In conditions as close to combat as possible, using pyrotechnics.
#  - You can choose games (and suggest your own) in the [form](https://forms.gle/yEzCFtnhnVYeuiCA6):
#  - Donating is voluntary and free, but there will be small treats waiting for you from our partners.
#  - We are revealing from the heart information about discounts on products at the bakery.
#  - In the evening from 19:00 to 21:00, there is a 20% discount on all baked goods, pies, and pastries.
#  - In the morning from 8:00 to 11:00, there is a 30% discount.
#  - There is also a promotion on pizza 1+1=3.
#  - As a secret, we will tell you that the establishment has a 10% discount for students, and also a 35% discount for blood donors with a certificate.
#  - **Make a water reserve!
#  - Also, LARGE POTS are very much needed.
#  - They can be reused later, as sodium acetate is a food additive.
#  - Please, pots are extremely necessary!
#  - We would like to draw your attention to the fact that at Igor Sikorsky Kyiv Polytechnic Institute, the program for separate waste collection has been restored, as required by the Law of Ukraine "On Waste Management."
#  - Separate waste collection means collecting waste separately based on its type, characteristics, and composition in a way that facilitates its further processing.
#  - ✅ You should throw away waste such as glass, paper, plastic, and small metal containers from drinks into the mesh-type container.
#  - This project is attractive not only from an economic point of view, as it will reduce waste disposal costs, but it is also very important for preserving the cleanliness of our environment.
#  - ❤️ We hope for your understanding of the necessity of separate waste collection on the territory of Igor Sikorsky Kyiv Polytechnic Institute!
#  - We are looking for talented artists to participate.
#  - For those who wish to delight guests with handmade products, there is an opportunity to sell your goods.
#  - These can be jewelry, candles, toys, sweets, etc.
#  - However, we still have a little batter left for pancakes.
#  - If you wish, we can also hold a small workshop on making motanka dolls.
#  - There will be tea/coffee 💰 and an opportunity to support the collection for a student of the IEE.
#  - Please stock up on water.
#  - 🏃🏼‍♀️**Sports:** tug of war, darts, table tennis, arm wrestling, board games, chess, table football.
#  - **
# 📸**PHOTO ZONE**
# 👑**Beauty Zone**: body art, mehendi tattoos, face painting, and more.
#  - **Inventory**
# From June 5 to June 7, an inventory commission will check the current state of inventory in the rooms.
#  - Design, coding, soldering, testing - there are plenty of places for working hands.
#  - Please note that the water pressure has dropped; it may be worth storing some water.
#  - ** **It is strictly prohibited:** 😡To flush down the toilets: hygiene products, bags, cotton pads, cotton swabs, wet wipes, food scraps (and not just scraps), vegetables, fruits, socks and underwear, dead fish and hamsters.
#  - 😡To pour down sinks and washbasins: used tea leaves, coffee grounds, hot grease, food scraps, etc.
#  - **Inventory**
# From June 5 to 7, an inventory commission will check the current state of inventory in the rooms.
#  - Consume alcohol responsibly.
#  - Do not forget to extinguish cigarette butts if you decide to smoke.
#  - **Priority Categories:**
# 1.
#  - Those who are on the [lists of in-person disciplines](https://t.me/sr_kpi/4925).
#
# Cluster 7:
#  - People from ONT/TOT, children of parents with combatant status, orphans, and children deprived of parental care.
#  - **Exceptions include:**
# • people with ONT/TOT;
# • applicants who plan to enter graduate school (for this, a submission from the faculty is required).
#  - People with ONT/TOT, children of parents with disabilities, orphans, and children deprived of parental care.
#
# Cluster 5:
#  - The deep plot will not leave you indifferent.
#
# Cluster 2:
#  - The film embodies the clash of empires, the hopelessness of occupation, and the trap of World War II.
#  - After the start of the full-scale invasion, he went to defend his homeland.
#  - While carrying a wounded comrade from the battlefield during a heavy fight, he died as a hero.
#  - The guys are fighting without state support and need financial assistance for servicing cannons, drones, and equipment.
#
# Cluster 6:
#  - 🕯**A graduate of the Faculty of Electrical Engineering and Automation, Yevhen Oleksandrovych Yurdyha, gave his life for the independence of Ukraine.
#  - **
#
# Yevhen graduated from our faculty in 2012 with a specialization in "Electric Stations".
#  - He then worked at Yudjin Energy.
#
# Cluster 4:
#  - The EEA team expresses sincere condolences to the family and friends of the deceased.
# C:\python\Lib\site-packages\sklearn\cluster\_agglomerative.py:1006: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
# Create a DataFrame from the original sentences and their corresponding cluster assignments
clustered_df = pd.DataFrame({
    'sentence': split_reviews,
    'cluster_id': cluster_assignment
})

# Check if the original data is loaded correctly as a DataFrame
if isinstance(data, pd.DataFrame):
    # Merge the original DataFrame with the clustered DataFrame on the sentence
    # Use 'outer' merge to keep all original sentences
    data_with_clusters = pd.merge(data, clustered_df, on='sentence', how='outer')
else:
    print("Error: 'data' is not a DataFrame. Please check the loading of 'Without_pos.csv'.")

# Display the updated DataFrame
print("\nUpdated DataFrame with Cluster ID:")
data_with_clusters.head(20)
# Out:
# Updated DataFrame with Cluster ID:
#                          date        channel_name  message_id  \
# 0   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 1   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 2   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 3   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 4   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 5   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 6   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 7   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 8   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 9   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 10  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 11  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 12  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 13  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 14  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 15  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 16  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 17  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 18  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 19  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
#
#                                                  text sentiment  \
# 0   **🌡️ Repair work on heating networks**\n\nToda...  negative
# 1   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 2   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 3   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 4   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 5   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 6   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 7   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 8   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 9   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 10  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 11  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 12  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 13  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 14  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 15  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 16  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 17  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 18  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 19  **🌡️ Repair work on heating networks**\n\nToda...   neutral
#
#                                        rephrased_news  \
# 0   Repair work on heating networks has resulted i...
# 1   Repair work on heating networks has resulted i...
# 2   Repair work on heating networks has resulted i...
# 3   Repair work on heating networks has resulted i...
# 4   Repair work on heating networks has resulted i...
# 5   Repair work on heating networks has resulted i...
# 6   Repair work on heating networks has resulted i...
# 7   Repair work on heating networks has resulted i...
# 8   Repair work on heating networks has resulted i...
# 9   Repair work on heating networks has resulted i...
# 10  Repair work on heating networks has resulted i...
# 11  Repair work on heating networks has resulted i...
# 12  Repair work on heating networks has resulted i...
# 13  Repair work on heating networks has resulted i...
# 14  Repair work on heating networks has resulted i...
# 15  Repair work on heating networks has resulted i...
# 16  Repair work on heating networks has resulted i...
# 17  Repair work on heating networks has resulted i...
# 18  Repair work on heating networks has resulted i...
# 19  Repair work on heating networks has resulted i...
#
#                             title               topic   location_type  \
# 0   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 1   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 2   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 3   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 4   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 5   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 6   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 7   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 8   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 9   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 10  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 11  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 12  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 13  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 14  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 15  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 16  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 17  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 18  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 19  Heating Outage in Dormitories  Citizen Discomfort  exact location
#
#                location   latitude  longitude  \
# 0   ['KPI Dormitory 7']  50.448522  30.449409
# 1   ['KPI Dormitory 7']  50.448522  30.449409
# 2   ['KPI Dormitory 7']  50.448522  30.449409
# 3   ['KPI Dormitory 7']  50.448522  30.449409
# 4   ['KPI Dormitory 7']  50.448522  30.449409
# 5   ['KPI Dormitory 7']  50.448522  30.449409
# 6   ['KPI Dormitory 7']  50.448522  30.449409
# 7   ['KPI Dormitory 7']  50.448522  30.449409
# 8   ['KPI Dormitory 7']  50.448522  30.449409
# 9   ['KPI Dormitory 7']  50.448522  30.449409
# 10  ['KPI Dormitory 7']  50.448522  30.449409
# 11  ['KPI Dormitory 7']  50.448522  30.449409
# 12  ['KPI Dormitory 7']  50.448522  30.449409
# 13  ['KPI Dormitory 7']  50.448522  30.449409
# 14  ['KPI Dormitory 7']  50.448522  30.449409
# 15  ['KPI Dormitory 7']  50.448522  30.449409
# 16  ['KPI Dormitory 7']  50.448522  30.449409
# 17  ['KPI Dormitory 7']  50.448522  30.449409
# 18  ['KPI Dormitory 7']  50.448522  30.449409
# 19  ['KPI Dormitory 7']  50.448522  30.449409
#
#                                              sentence  cluster_id
# 0   **🌡️ Repair work on heating networks**\n\nToda...         0.0
# 1     Estimated return time: 12:00 PM on November 12.         0.0
# 2                                          @kpicampus         0.0
# 3                                          @kpicampus         0.0
# 4                                          @kpicampus         0.0
# 5                                          @kpicampus         0.0
# 6                                          @kpicampus         0.0
# 7                                          @kpicampus         0.0
# 8                                          @kpicampus         0.0
# 9                                          @kpicampus         0.0
# 10                                         @kpicampus         0.0
# 11                                         @kpicampus         0.0
# 12                                         @kpicampus         0.0
# 13                                         @kpicampus         0.0
# 14                                         @kpicampus         0.0
# 15                                         @kpicampus         0.0
# 16                                         @kpicampus         0.0
# 17                                         @kpicampus         0.0
# 18                                         @kpicampus         0.0
# 19                                         @kpicampus         0.0

# %%
# # Save the updated DataFrame to a new CSV file if needed
# data_with_clusters.to_csv('clustered.csv', index=False)

# %%
# Функція для отримання відповіді GPT для кожного кластеру
from openai import OpenAI

def get_gpt_response(user_prompt, system_prompt="", model="gpt-4o-mini"):
    client = OpenAI(api_key='sk-jMEOk_AeFqsriX4e9WlvXuiW6xdIiDWoIaImApR-3CT3BlbkFJVeXbABn_hQ3Hb23_XLNa0lxq6MKKRSQUc_PMoAPuYA')
    try:
        completion = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ]
        )
        response_text = completion.choices[0].message.content
        total_tokens = completion.usage.total_tokens
        return response_text, total_tokens
    except Exception as e:
        return f"An error occurred: {e}", 0

data = data_with_clusters

cluster_titles = {}
for cluster_id, cluster_sentences in clustered_reviews.items():
    user_prompt = f"""Based on these sentences, provide a short title (2-3 words) that highlights a public issue or concern reflected in the text: {cluster_sentences}.
    Ensure that the title contains no extra symbols or characters.
                      """
    
    # Get the cluster title
    response, tokens_used = get_gpt_response(user_prompt)
    
    # Store the result
    cluster_titles[cluster_id] = response
    print(f"Cluster {cluster_id} title: {response}")

# Add the cluster titles to the DataFrame
data['cluster_title'] = data['cluster_id'].map(cluster_titles)
# Out:
# Cluster 0 title: Heating and Water Issues
# Cluster 3 title: Public Engagement Concerns
# Cluster 1 title: Waste Management Concerns
# Cluster 7 title: Vulnerable Children
# Cluster 5 title: Social Indifference
# Cluster 2 title: War and Sacrifice
# Cluster 6 title: Sacrifice for Independence
# Cluster 4 title: Grief and Loss

# %%
# Display the updated DataFrame with the new Cluster Title column
data.head(20)
# Out:
#                          date        channel_name  message_id  \
# 0   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 1   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 2   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 3   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 4   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 5   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 6   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 7   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 8   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 9   2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 10  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 11  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 12  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 13  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 14  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 15  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 16  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 17  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 18  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 19  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
#
#                                                  text sentiment  \
# 0   **🌡️ Repair work on heating networks**\n\nToda...  negative
# 1   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 2   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 3   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 4   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 5   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 6   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 7   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 8   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 9   **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 10  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 11  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 12  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 13  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 14  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 15  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 16  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 17  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 18  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 19  **🌡️ Repair work on heating networks**\n\nToda...   neutral
#
#                                        rephrased_news  \
# 0   Repair work on heating networks has resulted i...
# 1   Repair work on heating networks has resulted i...
# 2   Repair work on heating networks has resulted i...
# 3   Repair work on heating networks has resulted i...
# 4   Repair work on heating networks has resulted i...
# 5   Repair work on heating networks has resulted i...
# 6   Repair work on heating networks has resulted i...
# 7   Repair work on heating networks has resulted i...
# 8   Repair work on heating networks has resulted i...
# 9   Repair work on heating networks has resulted i...
# 10  Repair work on heating networks has resulted i...
# 11  Repair work on heating networks has resulted i...
# 12  Repair work on heating networks has resulted i...
# 13  Repair work on heating networks has resulted i...
# 14  Repair work on heating networks has resulted i...
# 15  Repair work on heating networks has resulted i...
# 16  Repair work on heating networks has resulted i...
# 17  Repair work on heating networks has resulted i...
# 18  Repair work on heating networks has resulted i...
# 19  Repair work on heating networks has resulted i...
#
#                             title               topic   location_type  \
# 0   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 1   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 2   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 3   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 4   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 5   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 6   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 7   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 8   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 9   Heating Outage in Dormitories  Citizen Discomfort  exact location
# 10  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 11  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 12  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 13  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 14  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 15  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 16  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 17  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 18  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 19  Heating Outage in Dormitories  Citizen Discomfort  exact location
#
#                location   latitude  longitude  \
# 0   ['KPI Dormitory 7']  50.448522  30.449409
# 1   ['KPI Dormitory 7']  50.448522  30.449409
# 2   ['KPI Dormitory 7']  50.448522  30.449409
# 3   ['KPI Dormitory 7']  50.448522  30.449409
# 4   ['KPI Dormitory 7']  50.448522  30.449409
# 5   ['KPI Dormitory 7']  50.448522  30.449409
# 6   ['KPI Dormitory 7']  50.448522  30.449409
# 7   ['KPI Dormitory 7']  50.448522  30.449409
# 8   ['KPI Dormitory 7']  50.448522  30.449409
# 9   ['KPI Dormitory 7']  50.448522  30.449409
# 10  ['KPI Dormitory 7']  50.448522  30.449409
# 11  ['KPI Dormitory 7']  50.448522  30.449409
# 12  ['KPI Dormitory 7']  50.448522  30.449409
# 13  ['KPI Dormitory 7']  50.448522  30.449409
# 14  ['KPI Dormitory 7']  50.448522  30.449409
# 15  ['KPI Dormitory 7']  50.448522  30.449409
# 16  ['KPI Dormitory 7']  50.448522  30.449409
# 17  ['KPI Dormitory 7']  50.448522  30.449409
# 18  ['KPI Dormitory 7']  50.448522  30.449409
# 19  ['KPI Dormitory 7']  50.448522  30.449409
#
#                                              sentence  cluster_id  \
# 0   **🌡️ Repair work on heating networks**\n\nToda...         0.0
# 1     Estimated return time: 12:00 PM on November 12.         0.0
# 2                                          @kpicampus         0.0
# 3                                          @kpicampus         0.0
# 4                                          @kpicampus         0.0
# 5                                          @kpicampus         0.0
# 6                                          @kpicampus         0.0
# 7                                          @kpicampus         0.0
# 8                                          @kpicampus         0.0
# 9                                          @kpicampus         0.0
# 10                                         @kpicampus         0.0
# 11                                         @kpicampus         0.0
# 12                                         @kpicampus         0.0
# 13                                         @kpicampus         0.0
# 14                                         @kpicampus         0.0
# 15                                         @kpicampus         0.0
# 16                                         @kpicampus         0.0
# 17                                         @kpicampus         0.0
# 18                                         @kpicampus         0.0
# 19                                         @kpicampus         0.0
#
#                cluster_title
# 0   Heating and Water Issues
# 1   Heating and Water Issues
# 2   Heating and Water Issues
# 3   Heating and Water Issues
# 4   Heating and Water Issues
# 5   Heating and Water Issues
# 6   Heating and Water Issues
# 7   Heating and Water Issues
# 8   Heating and Water Issues
# 9   Heating and Water Issues
# 10  Heating and Water Issues
# 11  Heating and Water Issues
# 12  Heating and Water Issues
# 13  Heating and Water Issues
# 14  Heating and Water Issues
# 15  Heating and Water Issues
# 16  Heating and Water Issues
# 17  Heating and Water Issues
# 18  Heating and Water Issues
# 19  Heating and Water Issues

# %%
# data.to_csv('clustered_id.csv', index=False)
filtered_data = data.dropna(subset=['sentiment', 'sentence'])
filtered_data.head()
# filtered_data.to_csv('filtered_clustered_id.csv', index=False)
# Out:
#                         date        channel_name  message_id  \
# 0  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 1  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 2  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 3  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
# 4  2023-11-11T07:51:25+00:00  Dormitory 7 of KPI       392.0
#
#                                                 text sentiment  \
# 0  **🌡️ Repair work on heating networks**\n\nToda...  negative
# 1  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 2  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 3  **🌡️ Repair work on heating networks**\n\nToda...   neutral
# 4  **🌡️ Repair work on heating networks**\n\nToda...   neutral
#
#                                       rephrased_news  \
# 0  Repair work on heating networks has resulted i...
# 1  Repair work on heating networks has resulted i...
# 2  Repair work on heating networks has resulted i...
# 3  Repair work on heating networks has resulted i...
# 4  Repair work on heating networks has resulted i...
#
#                            title               topic   location_type  \
# 0  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 1  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 2  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 3  Heating Outage in Dormitories  Citizen Discomfort  exact location
# 4  Heating Outage in Dormitories  Citizen Discomfort  exact location
#
#               location   latitude  longitude  \
# 0  ['KPI Dormitory 7']  50.448522  30.449409
# 1  ['KPI Dormitory 7']  50.448522  30.449409
# 2  ['KPI Dormitory 7']  50.448522  30.449409
# 3  ['KPI Dormitory 7']  50.448522  30.449409
# 4  ['KPI Dormitory 7']  50.448522  30.449409
#
#                                             sentence  cluster_id  \
# 0  **🌡️ Repair work on heating networks**\n\nToda...         0.0
# 1    Estimated return time: 12:00 PM on November 12.         0.0
# 2                                         @kpicampus         0.0
# 3                                         @kpicampus         0.0
# 4                                         @kpicampus         0.0
#
#               cluster_title
# 0  Heating and Water Issues
# 1  Heating and Water Issues
# 2  Heating and Water Issues
# 3  Heating and Water Issues
# 4  Heating and Water Issues

# %%
# Завантажте ваш CSV файл
data = filtered_data

# Порахуйте кількість унікальних елементів у стовпці 'place_id'
unique_place_ids = data[['latitude','longitude', 'cluster_title','cluster_id', 'text','message_id','title']].nunique()

print(f'Number of unique place_id: {unique_place_ids}')
# Out:
# Number of unique place_id: latitude           8
# longitude          8
# cluster_title      8
# cluster_id         8
# text             149
# message_id       147
# title            136
# dtype: int64

# %%
# Вибираємо тільки необхідні колонки
selected_columns = data[['latitude','longitude', 'cluster_title','cluster_id', 'text','message_id','title']]

# Видаляємо повтори, якщо одночасно дублюються 'original_review' та 'Cluster Title'
small_data = selected_columns.drop_duplicates(subset=['text', 'cluster_title'])

small_data.head(10)
# Out:
#       latitude  longitude             cluster_title  cluster_id  \
# 0    50.448522  30.449409  Heating and Water Issues         0.0
# 81   50.448522  30.449409  Heating and Water Issues         0.0
# 160  50.448522  30.449409  Heating and Water Issues         0.0
# 239  50.448522  30.449409  Heating and Water Issues         0.0
# 318  50.448522  30.449409  Heating and Water Issues         0.0
# 397  50.448522  30.449409  Heating and Water Issues         0.0
# 476  50.448522  30.449409  Heating and Water Issues         0.0
# 555  50.449013  30.450868  Heating and Water Issues         0.0
# 634  50.449013  30.450868  Heating and Water Issues         0.0
# 713  50.449013  30.450868  Heating and Water Issues         0.0
#
#                                                   text  message_id  \
# 0    **🌡️ Repair work on heating networks**\n\nToda...       392.0
# 81   ⚠️ **Emergency**\n\nEmergency power outage acr...       402.0
# 160  💡**Power outages**\n\nStarting from May 16, ho...       404.0
# 239  🌡️ **Well, you get it**\n\n**Kyivteploenergo p...       405.0
# 318  🟢 **Directorate 06.08**\n\n**Settlement**\nWil...       406.0
# 397  [​​](https://telegra.ph/file/b793c7b6b4d653e40...       408.0
# 476  🌡 **Hot water outage**\n\n**Due to emergency w...       409.0
# 555  🟢 **Administration**\n\n**Masters**\nStudents ...       158.0
# 634  💧**May Without Water**\n\nThere is no hot wate...       161.0
# 713  **🟢 Administration**\n\n**Shelters**\nRepairs ...       162.0
#
#                                title
# 0      Heating Outage in Dormitories
# 81      Emergency Power Outage Alert
# 160   Hourly Power Outages Scheduled
# 239     Heating Work Delays Expected
# 318  Settlement and Hot Water Issues
# 397   Volunteers Needed for Settling
# 476      Hot Water Supply Disruption
# 555   Dormitory Updates for Students
# 634        Hot Water Outage Extended
# 713  Dormitory Repairs and Resources

# %%
# small_data.to_csv('final.csv', index=False)

# %%
import folium
import pandas as pd

# Завантажуємо датасет
data = small_data

# Підраховуємо кількість повторень для кожної локації
location_counts = data.groupby(['latitude', 'longitude']).size().reset_index(name='count')

# Ініціалізуємо карту, центруючи її на Київ
center_location = [50.4503596, 30.5245025]
m = folium.Map(location=center_location, zoom_start=12)

# Визначаємо кольори для маркерів
colors = ['red', 'blue', 'green', 'orange', 'purple', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen']

# Проходимо по кожній унікальній локації і додаємо маркери
for index, row in location_counts.iterrows():
    try:
        # Отримуємо кількість дублікатів для локації
        count = row['count']
        latitude = row['latitude']
        longitude = row['longitude']
        
        # Фільтруємо рядки з датасету, які відповідають цій локації
        location_reviews = data[(data['latitude'] == latitude) & (data['longitude'] == longitude)]
        
        # Формуємо текст для popup, включаючи всі відгуки для цієї локації
        popup_text = ""
        for _, review_row in location_reviews.iterrows():
            popup_text += f"Review: {review_row['text']}<br><br>"
        
        # Вибираємо колір випадковим чином або на основі якихось даних
        color = colors[index % len(colors)]
        
        # Робимо маркер більшим на основі кількості дублікатів
        radius = 5 + (count * 2)  # Базовий радіус + пропорційне збільшення

        # Додаємо круглий маркер для кожної локації
        folium.CircleMarker(
            [latitude, longitude],
            radius=radius,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7,
            popup=popup_text,
            tooltip=f"Location ({latitude}, {longitude}) - {count} reviews"
        ).add_to(m)
    except KeyError:
        # Пропускаємо записи, якщо немає координат або інших важливих полів
        continue

# Зберігаємо карту в HTML файл
m.save("problematic_reviews_clustered_map.html")

# Виводимо карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e60001fc246d0d38dcbe958c5c6fb7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e60001fc246d0d38dcbe958c5c6fb7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e60001fc246d0d38dcbe958c5c6fb7d = L.map(
#                 &quot;map_3e60001fc246d0d38dcbe958c5c6fb7d&quot;,
#                 {
#                     center: [50.4503596, 30.5245025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db2f9854b07915ec0666c1f1abd0661e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_db2f9854b07915ec0666c1f1abd0661e.addTo(map_3e60001fc246d0d38dcbe958c5c6fb7d);
#
#
#             var circle_marker_e5826fecf2b3f95118b5b1bbaa893fb3 = L.circleMarker(
#                 [50.4364983, 30.4283648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e60001fc246d0d38dcbe958c5c6fb7d);
#
#
#         var popup_45a845630c1cb522f0177c648dd9e194 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0d73bccf84fa9d53c90de5c607206f1 = $(`&lt;div id=&quot;html_c0d73bccf84fa9d53c90de5c607206f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Review: 🚰 **Message from the Future**  According to Kyivteploenergo, there will be no water supply starting tomorrow at 9:00 AM.  The estimated time for the return of water supply will be communicated by Kyivteploenergo tomorrow, based on the volume of work.  @kpicampus&lt;br&gt;&lt;br&gt;Review: UPD: The disconnection of hot water supply has been extended until June 10.  @kpicampus&lt;br&gt;&lt;br&gt;Review: 🟢 **Administration**  **Settlement** The settlement algorithm for the summer will be announced tomorrow, based on a similar, [last year&#x27;s principle](https://t.me/kpicampus/1580).  The number of settlement places for the next academic year is planned to increase by 1,500. Instructions for the settlement itself will be available by July 17.  **Elevators** Elevators are starting to resume operation, but it is necessary to monitor the disconnection schedules to avoid getting stuck in the elevator in the middle of the night.  **Inventory** From June 5 to June 7, an inventory commission will check the current state of inventory in the rooms.  @kpicampus&lt;br&gt;&lt;br&gt;Review: 🟢 **Administration 06.08**  **Settlement** It will start on August 26, and by the end of the week, there will be lists for settlement from faculties and institutes. A total of about 9,000 students are planned to be brought to mixed learning.  **Masters** By August 2, they should have written a [request](https://docs.google.com/document/d/13FJxmoUKzXYeRo9T8oGxshdi3MXm1faIDpQwAO6Tk1E/edit?usp=sharing) for a change in payment format and extension of residence in the dormitory until August 31.  If you did not write a request, please contact the manager.  **Hot Water** In some dormitories, there has been no hot water for 3 months due to major repair work.  **Elevators** Due to the stabilization of electricity supply, the operation of most elevators will be restored.  @kpicampus&lt;br&gt;&lt;br&gt;Review: 🌡 **Disconnection of Hot Water**  **Due to emergency work by Kyivteploenergo, there is no hot water in some dormitories.**  Hot water supply is planned to be restored by the evening of August 29.  @kpicampus&lt;br&gt;&lt;br&gt;Review: 💧 **Water Disconnection**  **Due to emergency work by Kyivteploenergo, there may be interruptions in water supply in some dormitories.**  Water supply is planned to be restored by 14:00 on September 16.  @kpicampus&lt;br&gt;&lt;br&gt;Review: **Promotion**  **Hot water has been turned off only for dormitory 8. A plumber is conducting repair work, and it should be ready by the evening.**&lt;br&gt;&lt;br&gt;Review: 🟢 **Administration**  **Settlement** The settlement algorithm for the summer will be announced tomorrow, based on a similar, [last year&#x27;s principle](https://t.me/kpicampus/1580).  The number of settlement places for the next academic year is planned to increase by 1,500. Instructions for the settlement itself will be available by July 17.  **Elevators** Elevators are starting to resume operation, but it is necessary to monitor the disconnection schedules to avoid getting stuck in the elevator in the middle of the night.  **Inventory** From June 5 to June 7, an inventory commission will check the cur

# %%
import uuid

def get_gpt_response(user_prompt, system_prompt="", model="gpt-4o-mini"):
    client = OpenAI(api_key='sk-jMEOk_AeFqsriX4e9WlvXuiW6xdIiDWoIaImApR-3CT3BlbkFJVeXbABn_hQ3Hb23_XLNa0lxq6MKKRSQUc_PMoAPuYA')
    try:
        completion = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ]
        )
        response_text = completion.choices[0].message.content
        total_tokens = completion.usage.total_tokens
        return response_text, total_tokens
    except Exception as e:
        return f"An error occurred: {e}", 0
        
# Створюємо функцію для виклику GPT або іншої обробки
def process_cluster_reviews(content):
    system_message = (
        "You are tasked with creating brief, informative summaries of user reviews or news content. "
        "These summaries should clearly describe the main problems or challenges mentioned, highlighting key issues from multiple perspectives when necessary. "
        "The summaries should aim to be interesting yet concise, so the reader can quickly grasp the core of the issue. Ensure that each summary captures the problem in a detailed, well-rounded manner, while remaining within 200 characters."
    )
    
    # Промпт для моделі GPT
    prompt = (
        "Step 1: Carefully read the review or news content. Focus on identifying the primary problem or issue mentioned, along with any potential consequences or implications.\n"
        "Step 2: Identify relevant supporting details that further clarify the problem. Consider any suggestions, concerns, or actions mentioned in the content that offer additional insight into the issue.\n"
        
        f"Content:\n{content}\n"
        
        "Step 3: Create a concise, clear summary (up to 200 characters) that integrates the key problem and supporting details. "
        "Aim to provide a well-rounded view of the issue, highlighting any relevant aspects such as the scope, impact, or potential solutions.\n"
        
        "Step 4: Ensure that the summary does not exceed 200 characters and is easy to understand. If the initial version exceeds the limit, refine it while keeping the most critical points. "
        "The final summary should capture the problem in a clear and engaging way, without omitting key information."
    )
    summary = get_gpt_response(prompt, system_message)
    return summary


# Функція для об'єднання і обробки коментарів по кластеру
def generate_summaries_by_location(df):
    summary_data = []

    # Групуємо дані по координатам і кластеру
    grouped = df.groupby(['latitude', 'longitude', 'cluster_title'])

    for (lat, lng, cluster_title), group in grouped:
        # Об'єднуємо всі коментарі в один текст
        combined_reviews = ' '.join(group['text'].tolist())

        # Викликаємо функцію для обробки тексту
        summary = process_cluster_reviews(combined_reviews)

        # Генеруємо унікальний ID для саммарі
        summary_id = str(uuid.uuid4())

        # Записуємо результат для кожного ряду групи
        for idx in group.index:
            summary_data.append({
                'index': idx,
                'summary': summary,
                'summary_id': summary_id
            })

    # Перетворюємо результат в DataFrame і об'єднуємо з оригінальним датафреймом
    summary_df = pd.DataFrame(summary_data)
    df = df.merge(summary_df, left_index=True, right_on='index').drop('index', axis=1)

    return df

# Викликаємо функцію для обробки
df = small_data  # Завантаження твого датафрейму
df_with_summaries = generate_summaries_by_location(df)

# Зберігаємо результати у новий CSV
df_with_summaries.to_csv('output_with_summaries.csv', index=False)

# Виводимо результат для перевірки
df_with_summaries.head(10)
# Out:
#       latitude  longitude             cluster_title  cluster_id  \
# 151  50.448522  30.449409  Heating and Water Issues         0.0
# 152  50.448522  30.449409  Heating and Water Issues         0.0
# 153  50.448522  30.449409  Heating and Water Issues         0.0
# 154  50.448522  30.449409  Heating and Water Issues         0.0
# 155  50.448522  30.449409  Heating and Water Issues         0.0
# 156  50.448522  30.449409  Heating and Water Issues         0.0
# 157  50.448522  30.449409  Heating and Water Issues         0.0
# 160  50.449013  30.450868  Heating and Water Issues         0.0
# 161  50.449013  30.450868  Heating and Water Issues         0.0
# 162  50.449013  30.450868  Heating and Water Issues         0.0
#
#                                                   text  message_id  \
# 151  **🌡️ Repair work on heating networks**\n\nToda...       392.0
# 152  ⚠️ **Emergency**\n\nEmergency power outage acr...       402.0
# 153  💡**Power outages**\n\nStarting from May 16, ho...       404.0
# 154  🌡️ **Well, you get it**\n\n**Kyivteploenergo p...       405.0
# 155  🟢 **Directorate 06.08**\n\n**Settlement**\nWil...       406.0
# 156  [​​](https://telegra.ph/file/b793c7b6b4d653e40...       408.0
# 157  🌡 **Hot water outage**\n\n**Due to emergency w...       409.0
# 160  🟢 **Administration**\n\n**Masters**\nStudents ...       158.0
# 161  💧**May Without Water**\n\nThere is no hot wate...       161.0
# 162  **🟢 Administration**\n\n**Shelters**\nRepairs ...       162.0
#
#                                title  \
# 151    Heating Outage in Dormitories
# 152     Emergency Power Outage Alert
# 153   Hourly Power Outages Scheduled
# 154     Heating Work Delays Expected
# 155  Settlement and Hot Water Issues
# 156   Volunteers Needed for Settling
# 157      Hot Water Supply Disruption
# 160   Dormitory Updates for Students
# 161        Hot Water Outage Extended
# 162  Dormitory Repairs and Resources
#
#                                                summary  \
# 151  (Major heating and hot water outages persist i...
# 152  (Major heating and hot water outages persist i...
# 153  (Major heating and hot water outages persist i...
# 154  (Major heating and hot water outages persist i...
# 155  (Major heating and hot water outages persist i...
# 156  (Major heating and hot water outages persist i...
# 157  (Major heating and hot water outages persist i...
# 160  (Masters students face eviction after winter s...
# 161  (Masters students face eviction after winter s...
# 162  (Masters students face eviction after winter s...
#
#                                summary_id
# 151  0c35eff3-6c67-4089-92f8-05e797a94888
# 152  0c35eff3-6c67-4089-92f8-05e797a94888
# 153  0c35eff3-6c67-4089-92f8-05e797a94888
# 154  0c35eff3-6c67-4089-92f8-05e797a94888
# 155  0c35eff3-6c67-4089-92f8-05e797a94888
# 156  0c35eff3-6c67-4089-92f8-05e797a94888
# 157  0c35eff3-6c67-4089-92f8-05e797a94888
# 160  be86421c-223c-4441-94e1-5537332ea9a2
# 161  be86421c-223c-4441-94e1-5537332ea9a2
# 162  be86421c-223c-4441-94e1-5537332ea9a2

# %%
df_with_summaries.to_csv('final3.csv', index=False)
